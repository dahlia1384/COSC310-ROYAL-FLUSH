# %% [markdown]
# # Week 5 - Lab 4 (2/6/2026)
#
# - Each member updated the Team on their status for their respective M2 tasks
# - Updated Jira: Since all team members still weren't done with their tasks, the internal deadline was extended from 2/6/2026 to 2/8/2026.
# - Went through FastAPI and Github automation in the lab
