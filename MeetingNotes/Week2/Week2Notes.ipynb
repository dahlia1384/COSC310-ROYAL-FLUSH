# %% [markdown]
# Week 2 - Lab 1 Meeting minutes (16/01/2026)
# - Formed project team and named the team "Royal Flush".
# - All the team members added themselves to a group on canvas.
# - Went over the team contract and discussed the guidlines and commitment expectations.
# - Signed and submitted the team contract to canvas.
# - Decided on a weekly meeting time outside of the lab
# - Discussed the project description, requirements, and overview.
