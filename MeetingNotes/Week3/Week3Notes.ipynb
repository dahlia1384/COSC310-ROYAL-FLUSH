# %% [markdown]
# # 23 rd Jan: Group meeting
# - distributed work for M1, setting up internal deadlines
#
# # 26 th Jan: Group meeting
# - after finishing indivisual work, we had a group meeting to join all the documents together for submittion
# - making updates and small changes for M1
